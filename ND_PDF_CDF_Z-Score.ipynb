# %%
import pandas as pd

# %%
dataset=pd.read_csv("PlacemntWithoutNull.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
import seaborn as sns

# %%
dtp=sns.distplot(dataset["ssc_p"])
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7236\2465649283.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   dtp=sns.distplot(dataset["ssc_p"])

# %%
# plotting gragh
from matplotlib import pyplot
from scipy.stats import norm
import seaborn as sns
ax = sns.distplot(dataset['ssc_p'],kde=True,kde_kws={'color':'blue'},color='Green')
pyplot.axvline(60,color='Red')
pyplot.axvline(70,color='Red')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_3456\49052931.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset['ssc_p'],kde=True,kde_kws={'color':'blue'},color='Green')

# %%
def get_pdf_probability(dataset,startRange,endRange):
    # plotting gragh
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startRange,color='Red')
    pyplot.axvline(endRange,color='Red')
    # generating sample
    sample=dataset
    # finding mean() and std()
    sample_mean=sample.mean()
    sample_std=sample.std()
    print("Mean = %.3f" % sample_mean)
    print("Standard deviation = %.3f" % sample_std)
    # finding distribution
    dist=norm(sample_mean,sample_std)
    # finding probabilities for the range of outcomes
    values=[value for value in range(startRange,endRange)]
    probabilities=[dist.pdf(value) for value in values ]
    prob=sum(probabilities)
    print("Area between the ({},{}) is {}". format(startRange,endRange,prob))
    return prob

# %%
get_pdf_probability(dataset["ssc_p"],60,70)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_3456\908869476.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean = 67.303
# Standard deviation = 10.827
# Area between the (60,70) is 0.3449514151280293
# 0.3449514151280293

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(dataset["ssc_p"])
ecdf(50)
# Out:
# 0.05581395348837209

# %%
#!pip install statsmodels
# Out:
# ...
#      ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.2 MB 1.3 MB/s eta 0:00:08
#      ---------------------------------------- 0.1/9.2 MB 762.6 kB/s eta 0:00:12
#      ---------------------------------------- 0.1/9.2 MB 656.4 kB/s eta 0:00:14
#      ---------------------------------------- 0.1/9.2 MB 656.4 kB/s eta 0:00:14
#       --------------------------------------- 0.1/9.2 MB 514.3 kB/s eta 0:00:18
#       --------------------------------------- 0.2/9.2 MB 577.4 kB/s eta 0:00:16
#       --------------------------------------- 0.2/9.2 MB 577.4 kB/s eta 0:00:16
#       --------------------------------------- 0.2/9.2 MB 476.3 kB/s eta 0:00:19
#       --------------------------------------- 0.2/9.2 MB 454.0 kB/s eta 0:00:20
#       --------------------------------------- 0.2/9.2 MB 445.2 kB/s eta 0:00:21
#       --------------------------------------- 0.2/9.2 MB 458.5 kB/s eta 0:00:20
# ...

# %%
sam_mean=dataset["ssc_p"].mean()
sam_std=dataset["ssc_p"].std()
values=[i for i in dataset["ssc_p"] ]
z_score=[ ((j-sam_mean) / sam_std) for j in values ]
sns.distplot(z_score,kde=True,kde_kws={'color':'black'},color='yellow')
sum(z_score)/len(z_score)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7236\1300285239.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True,kde_kws={'color':'black'},color='yellow')
# -4.2911410858767677e-16

# %%
#converting normal distribution to standard normal distribution
def stdND(dataset):
    sam_mean=dataset.mean()
    sam_std=dataset.std()
    values=[i for i in dataset ]
    z_score=[ ((j-sam_mean) / sam_std) for j in values ]
    sns.distplot(z_score,kde=True,kde_kws={'color':'black'},color='yellow')
    avg=sum(z_score)/len(z_score) 
    return avg

# %%
stdND(dataset["etest_p"])
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7236\3034826868.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True,kde_kws={'color':'black'},color='yellow')
# 7.126082669687051e-17
